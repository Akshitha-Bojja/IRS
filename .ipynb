# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-Bojja/IRS/blob/main/.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
synonyms = []
antonyms = []
for syn in wordnet.synsets("happy"):
            for l in syn.lemmas():
                   synonyms.append(l.name())
                   if l.antonyms():
                           antonyms.append(l.antonyms()[0].name())
print('Synonyms are :')
print(set(synonyms))
print('Antonyms are:')
print(set(antonyms))
# Out:
# Synonyms are :
# {'happy', 'glad', 'felicitous', 'well-chosen'}
# Antonyms are:
# {'unhappy'}
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# !pip install matplotlib wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text_data = "Bhavana Jamalpur . Word clouds are a fun way to visualize text!"
wordcloud = WordCloud(width=800, height=400,
background_color='white').generate(text_data)
plt.figure(figsize=(10, 5))

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
synonyms = []
antonyms = []
for syn in wordnet.synsets("happy"):
            for l in syn.lemmas():
                   synonyms.append(l.name())
                   if l.antonyms():
                           antonyms.append(l.antonyms()[0].name())
print('Synonyms are :')
print(set(synonyms))
print('Antonyms are:')
print(set(antonyms))

# !pip install matplotlib wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text_data = "Akshitha Akki . Word clouds are a fun way to visualize text!"
wordcloud = WordCloud(width=800, height=400,
background_color='white').generate(text_data)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Synonyms are :
# {'happy', 'glad', 'felicitous', 'well-chosen'}
# Antonyms are:
# {'unhappy'}
# ...
